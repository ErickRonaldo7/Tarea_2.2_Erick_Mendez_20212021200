# %%
import pandas as pd

datos = pd.read_csv('./housing.csv')
datos
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
datos.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
datos.hist(figsize=(15,8), bins=30, edgecolor="black")
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
datos = datos[datos['housing_median_age']<40] #filtra el limite fijo de 50, casas con mayor antiguedad no se agrupen en el limite.
datos = datos[datos['median_house_value']<500000]#evita tambien que casas con mayor precio de 500k se agrupen
datos = datos[datos['median_income']<15]#evita que los salarios medios se agrupen en el limite.
datos = datos[datos['population']>7000] #filtra la poblacion de la zona. (se explicara en el informe)

# %%
datos.hist(figsize=(15,8), bins=30, edgecolor="black")
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
datos.isnull().sum() #cuenta los nulos
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        1
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
datos = datos.dropna() #elimina los registros con nulos.

# %%
dummies_ocean = pd.get_dummies(datos["ocean_proximity"], dtype=int)#convierte a dummies las categorias de ocean_proximity

# %%
datos = pd.concat([datos, dummies_ocean], axis=1) #concatena al df original, datos.

# %%
datos = datos.drop(["ocean_proximity"], axis=1)#elimina categorias de ocean_proximty.

# %%
datos
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 570      -122.24     37.72                 5.0      18634.0          2885.0
# 864      -122.01     37.57                14.0      16199.0          2993.0
# 865      -122.04     37.58                14.0      14917.0          2708.0
# 871      -122.07     37.52                 3.0      14014.0          2861.0
# 922      -121.92     37.53                 7.0      28258.0          3864.0
# ...          ...       ...                 ...          ...             ...
# 18926    -122.17     38.08                 7.0      18392.0          2782.0
# 18985    -121.94     38.27                35.0      10869.0          2226.0
# 20249    -119.25     34.21                12.0      15201.0          2418.0
# 20451    -118.90     34.26                 5.0      25187.0          3521.0
# 20530    -121.76     38.57                11.0      15018.0          3008.0
#
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118 entries, 570 to 20530
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           118 non-null    float64
#  1   latitude            118 non-null    float64
#  2   housing_median_age  118 non-null    float64
#  3   total_rooms         118 non-null    float64
#  4   total_bedrooms      118 non-null    float64
#  5   population          118 non-null    float64
#  6   households          118 non-null    float64
#  7   median_income       118 non-null    float64
#  8   median_house_value  118 non-null    float64
#  9   <1H OCEAN           118 non-null    int64
#  10  INLAND              118 non-null    int64
#  11  NEAR BAY            118 non-null    int64
#  12  NEAR OCEAN          118 non-null    int64
# dtypes: float64(9), int64(4)
# memory usage: 12.9 KB

# %%
datos.corr() #correlacion
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.944560           -0.165452     0.051410
# latitude            -0.944560  1.000000            0.064979    -0.014996
# housing_median_age  -0.165452  0.064979            1.000000    -0.479823
# total_rooms          0.051410 -0.014996           -0.479823     1.000000
# total_bedrooms       0.030637 -0.025508           -0.285190     0.833101
# population          -0.019566 -0.009624           -0.063152     0.570362
# households          -0.018715  0.011709           -0.221935     0.803130
# median_income        0.013685 -0.051711           -0.419530     0.423470
# median_house_value  -0.003113 -0.101471           -0.145739     0.261021
# <1H OCEAN            0.246196 -0.359885            0.143904     0.057087
# INLAND              -0.060624  0.289132           -0.129716    -0.050323
# NEAR BAY            -0.469827  0.389689           -0.030699    -0.057151
# ...

# %%
import seaborn as sb
sb.set(rc={'figure.figsize': (15,8)})
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
sb.scatterplot(x=datos["median_house_value"], y=datos["population"]) #aqui se ve graficamente
#de por que filtrar population, para que no limite la pendiente a valores de x.
# Out:
# <Axes: xlabel='median_house_value', ylabel='population'>

# %%
datos.drop('INLAND', axis = 1, inplace = True)

# %%
datos["bedroom_ratio"] = datos["total_rooms"] / datos["total_bedrooms"] 

datos['habitaciones_den'] = datos['total_rooms']/ datos['households'] #habitaciones disponibles por cada area.
datos['mayor_esp_poder_adq'] = datos['median_income']/ datos['bedroom_ratio'] #habitaciones disponibles por poder adquisitivo.
datos['poder_adq'] = datos['median_income']/datos['population'] #poder adquisitivo por areas donde se encuentran las casas.

# %%
sb.set(rc={'figure.figsize': (15,8)})
sb.heatmap(datos.corr(), annot=True, cmap="YlGnBu")
#aqui se observa que las caracteristicas anteriores tienen una correlacion imortante con la etiqueta.
# Out:
# <Axes: >

# %%
X = datos.drop(["median_house_value"], axis=1)#caracteristicas(x).
y = datos["median_house_value"]#etiqueta. (y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42) #separacion de datos prueba y entrenamiento.

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()

# %%
modelo.fit(X_train, y_train)#entrenamiento
# Out:
# LinearRegression()

# %%
predicciones = modelo.predict(X_test)

# %%
comparativa = {"Prediccion": predicciones, "Valor Real": y_test}
pd.DataFrame(comparativa)
# Out:
#           Prediccion  Valor Real
# 11775  160999.450539    169300.0
# 13848  108747.512906    122100.0
# 922    387931.926275    451100.0
# 9166   226708.469044    194600.0
# 6297   253632.221212    226200.0
# 20451  295807.708087    321300.0
# 12194  149630.885985    162200.0
# 3177    34739.608233    106300.0
# 13890   77067.482708    137500.0
# 12215  193173.399588    212300.0
# 5924   309545.312194    358700.0
# 18349  229683.928471    387500.0
# 3603   174782.466869    160000.0
# 14931  283626.377009    233400.0
# 9145   235324.474091    195300.0
# 7361   131740.813151    154500.0
# 13387  172279.478840    132600.0
# 570    343552.007537    350700.0
# 15061  133803.410116    123200.0
# 17777  263589.910931    286500.0
# 12128  147756.975656    127200.0
# 9133   174821.461626    141800.0
# 14558  334254.060658    322500.0
# 9880    93245.902408    118800.0

# %%
modelo.score(X_train, y_train) #score de datos de entrenamiento >80
# Out:
# 0.8171008093327288

# %%
modelo.score(X_test, y_test) #score de datos de prueba.
# Out:
# 0.7700994876603976

# %%
from sklearn.metrics import mean_squared_error 
mse = mean_squared_error(y_test, predicciones)

# %%
import numpy as np
rmse = np.sqrt(mse)
rmse #aplica la raíz cuadrada a mse para obtener rmse
# Out:
# np.float64(46867.63268699651)

# %%
# Normalizacion de datos 
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
modelo.fit(X_train_scaled , y_train)
# Out:
# LinearRegression()

# %%
modelo.score(X_train_scaled, y_train) #score con datos noramlizados >80
# Out:
# 0.8171008093327286

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, predicciones)
mse
# Out:
# np.float64(2196574993.683224)

# %%
from sklearn.metrics import r2_score
import numpy as np

r2 = np.sqrt(mse)
r2
# Out:
# np.float64(46867.63268699651)

# %%
#*******************EJERCICIO #2: ARBOL DE DECISIONES DE REGRESION************************** 

from sklearn.tree import DecisionTreeRegressor

#se necesita un arbol de regresion 
modelo_arbol = DecisionTreeRegressor(max_depth=5)
modelo_arbol.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
prediccionesTree = modelo_arbol.predict(X_test)

# %%
modelo_arbol.score(X_test, y_test) #score a datos de prueba
# Out:
# 0.7580945789079816

# %%
modelo_arbol.score(X_train, y_train) #score a datos de entrenamiento
# Out:
# 0.9405348194312125

# %%
from sklearn.tree import plot_tree
from matplotlib import pyplot as plt

plt.figure(figsize=(100,80))
plot_tree(
    modelo_arbol,
    feature_names=X_train.columns,
    filled=True,
    label='none'
)
#Este arbol de decision muestra dependiendo de que caracteristicas se llega al final a un precio determinado.
# Out:
# [Text(0.5654761904761905, 0.9166666666666666, 'mayor_esp_poder_adq <= 0.889\n5641527043.911\n94\n210638.298'),
#  Text(0.2916666666666667, 0.75, 'mayor_esp_poder_adq <= 0.742\n1963377408.264\n55\n161930.909'),
#  Text(0.4285714285714286, 0.8333333333333333, 'True  '),
#  Text(0.15476190476190477, 0.5833333333333334, 'housing_median_age <= 24.0\n1301201927.083\n24\n130987.5'),
#  Text(0.09523809523809523, 0.4166666666666667, 'bedroom_ratio <= 4.932\n779995723.14\n22\n137913.636'),
#  Text(0.047619047619047616, 0.25, 'population <= 7011.5\n324740661.157\n11\n123545.455'),
#  Text(0.023809523809523808, 0.08333333333333333, '0.0\n1\n87200.0'),
#  Text(0.07142857142857142, 0.08333333333333333, '211905600.0\n10\n127180.0'),
#  Text(0.14285714285714285, 0.25, 'longitude <= -117.175\n822361487.603\n11\n152281.818'),
#  Text(0.11904761904761904, 0.08333333333333333, '634121728.395\n9\n144077.778'),
#  Text(0.16666666666666666, 0.08333333333333333, '3610000.0\n2\n189200.0'),
# ...
